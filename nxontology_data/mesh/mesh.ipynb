# %% [markdown]
# # Development notebook for creating a MeSH NXOntology via SPARQL queries

# %%
# type: ignore
# %load_ext autoreload
# %autoreload 2

import pandas as pd

from nxontology_data.mesh.mesh import MeshLoader
# from IPython.display import Image
# from networkx.drawing.nx_agraph import to_agraph

# %% [markdown]
# ## load RDF

# %%
# %%time
mesh_year = "2022"
rdf = MeshLoader.get_mesh_rdf(mesh_year)
# Out:
# CPU times: user 9min 38s, sys: 10.8 s, total: 9min 49s
# Wall time: 10min 3s

# %% [markdown]
# ## subclass graph

# %%
vocab = MeshLoader.create_vocab_digraph(rdf)
# gviz = to_agraph(vocab)
# gviz.layout("dot")
# Image(gviz.draw(format="png"))

# %% [markdown]
# ## identifiers

# %%
# %%time
id_df = MeshLoader.run_query(rdf, "identifiers", cache=True)
id_df.head(2)
# Out:
# CPU times: user 17min 23s, sys: 4.46 s, total: 17min 27s
# Wall time: 17min 28s
#    mesh_id    mesh_class                                 mesh_uri  \
# 0  C000002  SCR_Chemical  http://id.nlm.nih.gov/mesh/2022/C000002
# 1  C000006  SCR_Chemical  http://id.nlm.nih.gov/mesh/2022/C000006
#
#          mesh_label mesh_date_created mesh_date_revised mesh_date_established  \
# 0          bevonium        1971-01-01        2018-09-24                  None
# 1  insulin, neutral        1971-01-01        2017-10-04                  None
#
#    mesh_frequency                              mesh_description
# 0             1.0               structure given in first source
# 1           263.0  a neutral, buffered solution of pork insulin

# %%
id_df.mesh_class.value_counts()
# Out:
# Term                      843575
# Concept                   457296
# SCR_Chemical              246750
# SCR_Organism               65233
# TopicalDescriptor          29607
# SCR_Disease                 6540
# SCR_Protocol                1217
# GeographicalDescriptor       398
# PublicationType              187
# Qualifier                     76
# CheckTag                       2
# Name: mesh_class, dtype: int64

# %%
# missing labels
# id_df[id_df.mesh_label.isna()]
id_df.mesh_label.isna().sum()
# Out:
# 0

# %%
# duplicate rows
# id_df[id_df.mesh_id.duplicated(keep=False)]
id_df.mesh_id.duplicated().any()
# Out:
# False

# %%
id_df.query("mesh_class=='Qualifier'").head(2)
# Out:
#            mesh_id mesh_class                                    mesh_uri  \
# 807230  Q000000981  Qualifier  http://id.nlm.nih.gov/mesh/2022/Q000000981
# 807231     Q000002  Qualifier     http://id.nlm.nih.gov/mesh/2022/Q000002
#
#                 mesh_label mesh_date_created mesh_date_revised  \
# 807230  diagnostic imaging        2016-06-29        2016-06-08
# 807231       abnormalities        1973-12-27        2015-07-01
#
#        mesh_date_established  mesh_frequency  \
# 807230            2017-01-01             NaN
# 807231            1966-01-01             NaN
#
#                                          mesh_description
# 807230  subheading only; coordinate with specific  ima...
# 807231  subhead only; congenital & structural only: do...

# %% [markdown]
# ## tree numbers

# %%
# %%time
tree_number_df = MeshLoader.run_query(rdf, "tree-numbers", cache=True)
tree_number_df.head(4)
# Out:
# CPU times: user 18.8 s, sys: 4.02 ms, total: 18.8 s
# Wall time: 18.8 s
#    mesh_id          tree_number
# 0  D000001  D03.633.100.221.173
# 1  D000002  D02.705.400.625.800
# 2  D000002  D02.705.539.345.800
# 3  D000002  D02.886.300.692.800

# %% [markdown]
# ## load into networkx
#
# Currently, the ontology excludes qualifiers and descriptor-qualifier pairs. Future work should determine how to handle these instances.

# %%
# %%time
nxo = MeshLoader.create_nxo(rdf, year_yyyy=mesh_year)
nxo.n_nodes, nxo.graph.number_of_edges()

# %%
id_df["in_nxo"] = id_df.mesh_id.isin(set(nxo.graph))
id_df.head(2)
# Out:
#    mesh_id    mesh_class                                 mesh_uri  \
# 0  C000002  SCR_Chemical  http://id.nlm.nih.gov/mesh/2021/C000002
# 1  C000006  SCR_Chemical  http://id.nlm.nih.gov/mesh/2021/C000006
#
#          mesh_label  in_nxo
# 0          bevonium    True
# 1  insulin, neutral    True

# %%
pd.crosstab(id_df.mesh_class, id_df.in_nxo).reset_index()
# Out:
# in_nxo              mesh_class   False    True
# 0                     CheckTag       0       2
# 1                      Concept  454398       0
# 2       GeographicalDescriptor       0     397
# 3              PublicationType       0     187
# 4                    Qualifier      76       0
# 5                 SCR_Chemical       0  245164
# 6                  SCR_Disease       0    6526
# 7                 SCR_Organism       0   65256
# 8                 SCR_Protocol       0    1217
# 9                         Term  835307       0
# 10           TopicalDescriptor       0   29331

# %%
# Nodes in graph that are not in the id_df. e.g. Descriptor Qualifier Pairs
assert len(set(nxo.graph) - set(id_df.mesh_id)) == 0

# %%
# %%time
top_map_df = MeshLoader.create_top_level_map_df(nxo)
top_map_df.head()
# Out:
# CPU times: user 29.3 s, sys: 172 ms, total: 29.5 s
# Wall time: 29.5 s
#         mesh_id    mesh_label         mesh_class top_mesh_id top_tree_number  \
# 466639  D001829  Body Regions  TopicalDescriptor     D001829             A01
# 466849  D001940        Breast  TopicalDescriptor     D001829             A01
# 472065  D005121   Extremities  TopicalDescriptor     D001829             A01
# 473889  D006257          Head  TopicalDescriptor     D001829             A01
# 478907  D009333          Neck  TopicalDescriptor     D001829             A01
#
#        top_mesh_label  top_is_disease  depth
# 466639   Body Regions           False      0
# 466849   Body Regions           False      1
# 472065   Body Regions           False      1
# 473889   Body Regions           False      1
# 478907   Body Regions           False      1

# %%
# top level terms and the number of descendants by class
top_summary_df = (
    top_map_df
    [["top_mesh_id", "top_tree_number", "top_mesh_label", "top_is_disease"]]
    .drop_duplicates()
    .merge(
        top_map_df
        .groupby(["top_mesh_id", "mesh_class"])
        .size()
        .reset_index(name='n_descendants')
        .pivot_table(index="top_mesh_id", columns="mesh_class", values="n_descendants", fill_value=0)
        .reset_index()
    )
)
top_summary_df.head(2)
# Out:
#   top_mesh_id top_tree_number          top_mesh_label  top_is_disease  \
# 0     D001829             A01            Body Regions           False
# 1     D009141             A02  Musculoskeletal System           False
#
#    GeographicalDescriptor  SCR_Chemical  SCR_Disease  SCR_Organism  \
# 0                       0             1            7             0
# 1                       0             4            5             0
#
#    SCR_Protocol  TopicalDescriptor
# 0             0                266
# 1             0                242

# %% [markdown]
# ### disease subset

# %%
top_summary_df.query("top_is_disease").drop(
    columns=["GeographicalDescriptor", "SCR_Organism", "SCR_Protocol"]
)
# Out:
#    top_mesh_id top_tree_number  \
# 26     D007239             C01
# 27     D009369             C04
# 28     D009140             C05
# 29     D004066             C06
# 30     D009057             C07
# 31     D012140             C08
# 32     D010038             C09
# 33     D009422             C10
# 34     D005128             C11
# 35     D052801             C12
# 36     D005261             C13
# 37     D002318             C14
# 38     D006425             C15
# 39     D009358             C16
# 40     D017437             C17
# 41     D009750             C18
# 42     D004700             C19
# 43     D007154             C20
# 44     D007280             C21
# 45     D000820             C22
# 46     D013568             C23
# 47     D009784             C24
# 48     D064419             C25
# 72     D001523             F03
#
#                                        top_mesh_label  top_is_disease  \
# 26                                         Infections            True
# 27                                          Neoplasms            True
# 28                           Musculoskeletal Diseases            True
# 29                          Digestive System Diseases            True
# 30                            Stomatognathic Diseases            True
# 31                         Respiratory Tract Diseases            True
# 32                      Otorhinolaryngologic Diseases            True
# 33                            Nervous System Diseases            True
# 34                                       Eye Diseases            True
# 35                           Male Urogenital Diseases            True
# 36  Female Urogenital Diseases and Pregnancy Compl...            True
# 37                            Cardiovascular Diseases            True
# 38                       Hemic and Lymphatic Diseases            True
# 39  Congenital, Hereditary, and Neonatal Diseases ...            True
# 40                Skin and Connective Tissue Diseases            True
# 41                 Nutritional and Metabolic Diseases            True
# 42                          Endocrine System Diseases            True
# 43                             Immune System Diseases            True
# 44                  Disorders of Environmental Origin            True
# 45                                    Animal Diseases            True
# 46        Pathological Conditions, Signs and Symptoms            True
# 47                              Occupational Diseases            True
# 48                       Chemically-Induced Disorders            True
# 72                                   Mental Disorders            True
#
#     SCR_Chemical  SCR_Disease  TopicalDescriptor
# 26             1          119                798
# 27             0          401                704
# 28             0         1750                392
# 29             0          302                321
# 30             0          354                229
# 31             1          162                247
# 32             0          409                132
# 33             0         2335                998
# 34             0          910                270
# 35             0          434                265
# 36             0          502                395
# 37             0          543                451
# 38             6          433                295
# 39             0         4115                788
# 40             0          887                490
# 41             1         1050                383
# 42             0          508                180
# 43             6          296                271
# 44             0            0                  5
# 45             0            5                164
# 46             1         2102               1114
# 47             0            5                 27
# 48             0            9                135
# 72             1          714                276

# %%
all_diseases = set(top_map_df.query("top_is_disease").mesh_id)
len(all_diseases)
# Out:
# 11251

# %% [markdown]
# ## GitHub outputs

# %%
gh_data_url = "https://github.com/related-sciences/nxontology-data/raw/output/mesh/"

# %%
pd.read_json(f"{gh_data_url}mesh_topical_descriptor_descendants_top_level_map.json.gz").sample(5, random_state=0)
# Out:
#            mesh_id                                         mesh_label  \
# 36053   C000664754                            Calonectria longiramosa
# 420240     C474744                            GP90-MC301 protein, rat
# 102707     C543241  Cardiomyopathy, fatal fetal, due to myocardial...
# 146679     C038055                      N-nitrosomethyl-N-propylamine
# 572839  C000725016                         Sauk-Suiattle Indian Tribe
#
#             mesh_class top_mesh_id top_tree_number  \
# 36053     SCR_Organism     D056890             B01
# 420240    SCR_Chemical     D000602             D12
# 102707     SCR_Disease     D013568             C23
# 146679    SCR_Chemical     D009930             D02
# 572839  SCR_Population     D011154             N01
#
#                                      top_mesh_label  top_is_disease  depth
# 36053                                     Eukaryota           False      4
# 420240          Amino Acids, Peptides, and Proteins           False      3
# 102707  Pathological Conditions, Signs and Symptoms            True      4
# 146679                            Organic Chemicals           False      3
# 572839                   Population Characteristics           False      5

# %%
pd.read_json(f"{gh_data_url}mesh_identifiers.json.gz").drop_duplicates("mesh_class")
# Out:
#            mesh_id              mesh_class  \
# 0          C000002            SCR_Chemical
# 2346    C000591739             SCR_Disease
# 15848   C000612320            SCR_Organism
# 93595   C000705129            SCR_Protocol
# 98889   C000724254          SCR_Population
# 321747     D000001       TopicalDescriptor
# 321964  D000068036         PublicationType
# 321965  D000068037  GeographicalDescriptor
# 329835     D005260                CheckTag
# 352201    M0000001                 Concept
# 812297  Q000000981               Qualifier
# 812373     T000001                    Term
#
#                                           mesh_uri  \
# 0          http://id.nlm.nih.gov/mesh/2023/C000002
# 2346    http://id.nlm.nih.gov/mesh/2023/C000591739
# 15848   http://id.nlm.nih.gov/mesh/2023/C000612320
# 93595   http://id.nlm.nih.gov/mesh/2023/C000705129
# 98889   http://id.nlm.nih.gov/mesh/2023/C000724254
# 321747     http://id.nlm.nih.gov/mesh/2023/D000001
# 321964  http://id.nlm.nih.gov/mesh/2023/D000068036
# 321965  http://id.nlm.nih.gov/mesh/2023/D000068037
# 329835     http://id.nlm.nih.gov/mesh/2023/D005260
# 352201    http://id.nlm.nih.gov/mesh/2023/M0000001
# 812297  http://id.nlm.nih.gov/mesh/2023/Q000000981
# 812373     http://id.nlm.nih.gov/mesh/2023/T000001
#
#                                                mesh_label mesh_date_created  \
# 0                                                bevonium        1971-01-01
# 2346    familial gynecomastia, due to increased aromat...        2014-11-04
# 15848                                   UR2 sarcoma virus        2017-10-18
# 93595                                          LAMP assay        2020-03-28
# 98889   Big Sandy Rancheria of Western Mono Indians of...        2022-11-29
# 321747                                         Calcimycin        1974-11-19
# 321964                                      Graphic Novel        2015-07-01
# 321965                                        South Sudan        2015-07-01
# 329835                                             Female        1999-01-01
# 352201                                         Calcimycin              None
# 812297                                 diagnostic imaging        2016-06-29
# 812373                                            A-23187        1990-03-08
#
#        mesh_date_revised mesh_date_established  mesh_frequency  \
# 0             2018-09-24                  None             1.0
# 2346          2022-11-02                  None             5.0
# 15848         2020-09-30                  None             0.0
# 93595         2020-03-31                  None           930.0
# 98889         2022-11-29                  None             0.0
# 321747        2016-05-27            1984-01-01             NaN
# 321964        2019-07-05            2016-01-01             NaN
# 321965        2021-01-26            2016-01-01             NaN
# 329835        2015-06-10            1966-01-01             NaN
# 352201              None                  None             NaN
# 812297        2016-06-08            2017-01-01             NaN
# 812373              None                  None             NaN
#
#                                          mesh_description  \
# 0                         structure given in first source
# 2346                                                 None
# 15848                                                None
# 93595   for use of LAMP assay for detecting COVID-19 a...
# 98889                                                None
# 321747                                               None
# 321964  This heading is used as a Publication Type. Gr...
# 321965                                               None
# 329835  check tag only for female organs, diseases, ph...
# 352201  An ionophorous, polyether antibiotic from Stre...
# 812297  subheading only; coordinate with specific  ima...
# 812373                                               None
#
#                  tree_numbers  in_full_nxo  in_desc_nxo
# 0                        None         True         True
# 2346                     None         True         True
# 15848                    None         True         True
# 93595                    None         True         True
# 98889                    None         True         True
# 321747  [D03.633.100.221.173]         True         True
# 321964          [V02.700.415]         True        False
# 321965  [Z01.058.290.120.745]         True        False
# 329835                   None         True        False
# 352201                   None        False        False
# 812297              [Y04.010]        False        False
# 812373                   None        False        False

# %%
pd.read_json(f"{gh_data_url}mesh_synonyms.json.gz").sample(5, random_state=0)
# Out:
#            mesh_id  concept_id     term_id  \
# 704006     C577955    M0581027     T836700
# 100718  C000674955  M000700981  T001033762
# 586186     C509465    M0497018     T671283
# 503573     C459630    M0430868     T503918
# 905742     D020526    M0328180  T000952246
#
#                                                mesh_label  \
# 704006  3-(2-chlorophenyl)-1-(2,4-dihydroxyphenyl)prop...
# 100718                                 Derxomyces nakasei
# 586186          meso-tetrakis(heptafluoropropyl)porphyrin
# 503573                       ent-beyer-15-en-18-O-oxalate
# 905742                             Brain Stem Infarctions
#
#                                     concept_label  \
# 704006                                     NPD170
# 100718                         Derxomyces nakasei
# 586186  meso-tetrakis(heptafluoropropyl)porphyrin
# 503573               ent-beyer-15-en-18-O-oxalate
# 905742                     Brain Stem Infarctions
#
#                                        term_label  concept_is_preferred  \
# 704006                                     NPD170                 False
# 100718                            Bullera nakasei                  True
# 586186  meso-tetrakis(heptafluoropropyl)porphyrin                  True
# 503573               ent-beyer-15-en-18-O-oxalate                  True
# 905742                        Brain Stem Infarcts                  True
#
#         term_is_preferred  term_label_is_preferred term_lexical_tag  \
# 704006               True                     True              LAB
# 100718              False                     True              NON
# 586186               True                     True              NON
# 503573               True                     True              NON
# 905742              False                    False              NON
#
#        term_date_created concept_relation_to_preferred
# 704006        2013-02-03                      narrower
# 100718        2020-03-26                         exact
# 586186        2006-04-13                         exact
# 503573        2002-07-14                         exact
# 905742        2019-02-26                         exact

# %%
pd.read_json(f"{gh_data_url}mesh_descriptor_qualifier_pairs.json.gz").sample(5, random_state=0)
# Out:
#                                 pair_label  pair_allowed  \
# 45319         Masked Mycotoxins/physiology           NaN
# 114717            Chromium Alloys/analysis           NaN
# 251852          o-Phthalaldehyde/standards           NaN
# 369654  HLA-B8 Antigen/cerebrospinal fluid           NaN
# 350916         Vertebral Artery/enzymology           NaN
#
#                              pair_type  \
# 45319   AllowedDescriptorQualifierPair
# 114717  AllowedDescriptorQualifierPair
# 251852  AllowedDescriptorQualifierPair
# 369654  AllowedDescriptorQualifierPair
# 350916  AllowedDescriptorQualifierPair
#
#                                                  pair_uri descriptor_id  \
# 45319   http://id.nlm.nih.gov/mesh/2023/D000083842Q000502    D000083842
# 114717     http://id.nlm.nih.gov/mesh/2023/D002858Q000032       D002858
# 251852     http://id.nlm.nih.gov/mesh/2023/D009764Q000592       D009764
# 369654     http://id.nlm.nih.gov/mesh/2023/D015795Q000134       D015795
# 350916     http://id.nlm.nih.gov/mesh/2023/D014711Q000201       D014711
#
#        qualifier_id   descriptor_label      qualifier_label use_instead_uri  \
# 45319       Q000502  Masked Mycotoxins           physiology            None
# 114717      Q000032    Chromium Alloys             analysis            None
# 251852      Q000592   o-Phthalaldehyde            standards            None
# 369654      Q000134     HLA-B8 Antigen  cerebrospinal fluid            None
# 350916      Q000201   Vertebral Artery           enzymology            None
#
#        use_instead_label use_instead_class
# 45319               None              None
# 114717              None              None
# 251852              None              None
# 369654              None              None
# 350916              None              None
